# %%
import cv2
from skimage.io import imread, imsave
import cv2
import numpy as np
from matplotlib import pyplot as plt
from scipy import ndimage
from skimage import measure, color, io
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import torch
import numpy as np
from PIL import Image
import tqdm
import pandas as pd
import pytorch_lightning as pl
import os
import copy
from sklearn.utils.class_weight import compute_class_weight

# %%
! git clone https://github.com/jlevy44/PreliminaryGenerativeHistoPath
# Out:
# Cloning into 'PreliminaryGenerativeHistoPath'...
# remote: Enumerating objects: 310, done.
# remote: Counting objects: 100% (310/310), done.
# remote: Compressing objects: 100% (309/309), done.
# remote: Total 310 (delta 1), reused 306 (delta 0), pack-reused 0
# Receiving objects: 100% (310/310), 15.28 MiB | 11.58 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
def load_convert_img(filepath=""):
    img=cv2.imread(filepath)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img

def make_image_mask(im):
    image=im[:,:int(im.shape[1]/2)]
    mask=im[:,int(im.shape[1]/2):]
    final_mask=np.zeros(image.shape[:2]).astype(int)
    final_mask[(mask[...,1]>220)&(mask[...,2]<50)]=1
    final_mask[(mask[...,2]>220)&(mask[...,1]<50)]=2
    return image,final_mask

def load_return_data(filepath=''):
    im=load_convert_img(filepath)
    image,final_mask=make_image_mask(im)
    return image,final_mask

# %%
img_masks_train=[load_return_data(f) for f in sorted(glob.glob("PreliminaryGenerativeHistoPath/cyto2label_public/train/*.png"))]
img_masks_val=[load_return_data(f) for f in sorted(glob.glob("PreliminaryGenerativeHistoPath/cyto2label_public/val/*.png"))]

train_imgs=list(map(lambda x: cv2.resize(x[0],(256,256),interpolation=cv2.INTER_CUBIC),img_masks_train))
train_masks=list(map(lambda x: np.concatenate([cv2.resize(x[1].astype(np.uint8),(256,256),interpolation=cv2.INTER_NEAREST).astype(np.uint8)[...,np.newaxis],np.zeros((256,256,2),dtype=np.uint8)],axis=2),img_masks_train))

val_imgs=list(map(lambda x: cv2.resize(x[0],(256,256),interpolation=cv2.INTER_CUBIC),img_masks_val))
val_masks=list(map(lambda x: np.concatenate([cv2.resize(x[1].astype(np.uint8),(256,256),interpolation=cv2.INTER_NEAREST).astype(np.uint8)[...,np.newaxis],np.zeros((256,256,2),dtype=np.uint8)],axis=2),img_masks_val))

# %%
! mkdir -p train/imgs train/labels val/imgs val/labels

# %%
for i,(im,lbl) in enumerate(zip(train_imgs,train_masks)):
    imsave(f"train/imgs/{i}.png",im)
    imsave(f"train/labels/{i}.png",lbl)
    
for i,(im,lbl) in enumerate(zip(val_imgs,val_masks)):
    imsave(f"test/imgs/{i}.png",im)
    imsave(f"test/labels/{i}.png",lbl)
# Out:
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/0.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/1.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/2.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/3.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/4.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/5.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/6.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/7.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/8.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/9.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/10.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/11.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/12.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/13.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/14.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/15.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/16.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/17.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/18.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/19.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/20.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/21.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/22.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/23.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/24.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/25.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/26.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/27.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/28.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/29.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/30.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/31.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/32.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/33.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/34.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/35.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/36.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/37.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/38.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/39.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/40.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/41.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/42.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/43.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/44.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/45.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/46.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/47.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/48.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/49.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/50.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/51.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/52.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/53.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/54.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/55.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/56.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/57.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/58.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/59.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/60.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/61.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/62.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/63.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/64.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/65.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/66.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/67.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/68.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/69.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/70.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/71.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/72.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/73.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/74.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/75.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/76.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/77.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/78.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/79.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/80.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/81.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/82.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/83.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/84.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/85.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/86.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/87.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/88.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/89.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/90.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/91.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/92.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/93.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/94.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/95.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/96.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/97.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/98.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: train/labels/99.png is a low contrast image
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/0.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/1.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/2.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/3.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/4.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/5.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/6.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/7.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/8.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/9.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/10.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/11.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/12.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/13.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/14.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/15.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/16.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/17.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/18.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/19.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/20.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/21.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/22.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/23.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/24.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/25.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/26.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/27.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/28.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/29.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/30.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/31.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/32.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/33.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/34.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/35.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/36.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/37.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/38.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/39.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/40.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/41.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/42.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/43.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/44.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/45.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/46.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/47.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/48.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/49.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/50.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/51.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/52.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/53.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/54.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/55.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/56.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/57.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/58.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/59.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/60.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/61.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/62.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/63.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/64.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/65.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/66.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/67.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/68.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/69.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/70.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/71.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/72.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/73.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/74.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/75.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/76.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/77.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/78.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/79.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/80.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/81.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/82.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/83.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/84.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/85.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/86.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/87.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/88.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/89.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/90.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/91.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/92.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/93.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/94.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/95.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/96.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/97.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/98.png is a low contrast image
#   import sys
# /Users/joshualevy/opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: val/labels/99.png is a low contrast image
#   import sys
